# %% [markdown]
# # 11장 실용적인 딥러닝을 위해

# %%
# 필요 라이브러리 선언
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# PDF 출력
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

# %% [markdown]
# ### 11.1 프레임워크의 활용

# %%
# 데이터 준비

# 변수 정의

# D: 입력 노드 개수
D = 784

# H: 은닉층의 노드 개수
H = 128

# 분류 클래스의 개수
num_classes = 10

# Keras 함수로 데이터 읽기
from keras.datasets import mnist
(x_train_org, y_train), (x_test_org, y_test) \
 = mnist.load_data()

# 입력 데이터의 가공(1차원)
x_train = x_train_org.reshape(-1, D) / 255.0
x_test = x_test_org.reshape((-1, D)) / 255.0

# 정답 데이터의 가공(원핫 인코딩)
from keras.utils import np_utils
y_train_ohe =\
 np_utils.to_categorical(y_train, num_classes)
y_test_ohe =\
 np_utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# 모델의 정의

# 필요 라이브러리 로딩
from keras.models import Sequential
from keras.layers import Dense

# Sequential 모델의 정의
model = Sequential()

# 은닉층1의 정의
model.add(Dense(H, activation='relu', input_shape=(D,)))

# 은닉층2의 정의
model.add(Dense(H, activation='relu'))

# 출력층
model.add(Dense(num_classes, activation='softmax'))

# 모델의 컴파일
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'sgd',
              metrics=['accuracy'])

# %%
# 학습 과정

# 학습의 단위
batch_size = 512

# 반복 횟수
nb_epoch = 50

# 모델의 학습
history1 = model.fit(
    x_train, 
    y_train_ohe,
    batch_size = batch_size, 
    epochs = nb_epoch,
    verbose = 1, 
    validation_data = (x_test, y_test_ohe))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 2s 13ms/step - loss: 2.1747 - accuracy: 0.2620 - val_loss: 1.6952 - val_accuracy: 0.6744
# Epoch 2/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.5427 - accuracy: 0.7029 - val_loss: 1.0658 - val_accuracy: 0.7839
# Epoch 3/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.9906 - accuracy: 0.7942 - val_loss: 0.7487 - val_accuracy: 0.8333
# Epoch 4/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.7311 - accuracy: 0.8278 - val_loss: 0.6012 - val_accuracy: 0.8523
# Epoch 5/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.5997 - accuracy: 0.8488 - val_loss: 0.5231 - val_accuracy: 0.8665
# Epoch 6/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.5244 - accuracy: 0.8652 - val_loss: 0.4701 - val_accuracy: 0.8788
# Epoch 7/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.4797 - accuracy: 0.8714 - val_loss: 0.4349 - val_accuracy: 0.8862
# Epoch 8/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.4458 - accuracy: 0.8802 - val_loss: 0.4090 - val_accuracy: 0.8901
# Epoch 9/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.4232 - accuracy: 0.8860 - val_loss: 0.3883 - val_accuracy: 0.8951
# Epoch 10/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.4024 - accuracy: 0.8911 - val_loss: 0.3723 - val_accuracy: 0.8967
# Epoch 11/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3841 - accuracy: 0.8951 - val_loss: 0.3593 - val_accuracy: 0.8997
# Epoch 12/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3718 - accuracy: 0.8971 - val_loss: 0.3488 - val_accuracy: 0.9025
# Epoch 13/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3593 - accuracy: 0.8999 - val_loss: 0.3389 - val_accuracy: 0.9062
# Epoch 14/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3524 - accuracy: 0.9011 - val_loss: 0.3295 - val_accuracy: 0.9067
# Epoch 15/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3429 - accuracy: 0.9028 - val_loss: 0.3225 - val_accuracy: 0.9092
# Epoch 16/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3298 - accuracy: 0.9075 - val_loss: 0.3167 - val_accuracy: 0.9108
# Epoch 17/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3273 - accuracy: 0.9091 - val_loss: 0.3099 - val_accuracy: 0.9113
# Epoch 18/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3250 - accuracy: 0.9081 - val_loss: 0.3062 - val_accuracy: 0.9128
# Epoch 19/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3186 - accuracy: 0.9087 - val_loss: 0.2991 - val_accuracy: 0.9136
# Epoch 20/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3086 - accuracy: 0.9128 - val_loss: 0.2950 - val_accuracy: 0.9166
# Epoch 21/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3059 - accuracy: 0.9148 - val_loss: 0.2898 - val_accuracy: 0.9176
# Epoch 22/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.2978 - accuracy: 0.9155 - val_loss: 0.2864 - val_accuracy: 0.9187
# Epoch 23/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2995 - accuracy: 0.9149 - val_loss: 0.2827 - val_accuracy: 0.9206
# Epoch 24/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2904 - accuracy: 0.9182 - val_loss: 0.2794 - val_accuracy: 0.9209
# Epoch 25/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2876 - accuracy: 0.9193 - val_loss: 0.2753 - val_accuracy: 0.9210
# Epoch 26/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2850 - accuracy: 0.9209 - val_loss: 0.2712 - val_accuracy: 0.9240
# Epoch 27/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2836 - accuracy: 0.9184 - val_loss: 0.2674 - val_accuracy: 0.9242
# Epoch 28/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2725 - accuracy: 0.9229 - val_loss: 0.2650 - val_accuracy: 0.9258
# Epoch 29/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2712 - accuracy: 0.9236 - val_loss: 0.2634 - val_accuracy: 0.9246
# Epoch 30/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2611 - accuracy: 0.9255 - val_loss: 0.2599 - val_accuracy: 0.9261
# Epoch 31/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2696 - accuracy: 0.9227 - val_loss: 0.2576 - val_accuracy: 0.9269
# Epoch 32/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2657 - accuracy: 0.9255 - val_loss: 0.2547 - val_accuracy: 0.9274
# Epoch 33/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2574 - accuracy: 0.9267 - val_loss: 0.2519 - val_accuracy: 0.9283
# Epoch 34/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2596 - accuracy: 0.9269 - val_loss: 0.2494 - val_accuracy: 0.9292
# Epoch 35/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2465 - accuracy: 0.9309 - val_loss: 0.2461 - val_accuracy: 0.9285
# Epoch 36/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2538 - accuracy: 0.9262 - val_loss: 0.2446 - val_accuracy: 0.9301
# Epoch 37/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2475 - accuracy: 0.9289 - val_loss: 0.2422 - val_accuracy: 0.9314
# Epoch 38/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2423 - accuracy: 0.9301 - val_loss: 0.2395 - val_accuracy: 0.9310
# Epoch 39/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2470 - accuracy: 0.9313 - val_loss: 0.2374 - val_accuracy: 0.9323
# Epoch 40/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2430 - accuracy: 0.9311 - val_loss: 0.2354 - val_accuracy: 0.9324
# Epoch 41/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2342 - accuracy: 0.9332 - val_loss: 0.2329 - val_accuracy: 0.9334
# Epoch 42/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2326 - accuracy: 0.9331 - val_loss: 0.2311 - val_accuracy: 0.9334
# Epoch 43/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2332 - accuracy: 0.9326 - val_loss: 0.2290 - val_accuracy: 0.9325
# Epoch 44/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2291 - accuracy: 0.9340 - val_loss: 0.2276 - val_accuracy: 0.9340
# Epoch 45/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2276 - accuracy: 0.9346 - val_loss: 0.2250 - val_accuracy: 0.9346
# Epoch 46/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2300 - accuracy: 0.9349 - val_loss: 0.2233 - val_accuracy: 0.9357
# Epoch 47/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2209 - accuracy: 0.9378 - val_loss: 0.2220 - val_accuracy: 0.9355
# Epoch 48/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2186 - accuracy: 0.9378 - val_loss: 0.2201 - val_accuracy: 0.9370
# Epoch 49/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2160 - accuracy: 0.9375 - val_loss: 0.2182 - val_accuracy: 0.9357
# Epoch 50/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2163 - accuracy: 0.9380 - val_loss: 0.2161 - val_accuracy: 0.9377

# %% [markdown]
# ## 11.4 수치미분

# %%
import numpy as np

# 네이피어 상수를 밑으로 하는 로그함수의 정의
def f(x):
    return np.exp(x)

# 아주 작은 수 h의 정의
h = 0.001

# f'(0)의 근사계산
# f'(0) = f(0) = 1에 가까워짐
diff = (f(0 + h) - f(0 - h))/(2 * h)

# 결과 확인
print(diff)
# Out:
# 1.0000001666666813

# %% [markdown]
# ## 11.5 고도의 학습법

# %% [markdown]
# ### SGD

# %%
# 필요 라이브러리 로딩
from keras.models import Sequential
from keras.layers import Dense

# 학습의 단위
batch_size = 512

# 반복 횟수
nb_epoch = 50

# %%
# Sequential 모델의 정의
model = Sequential()

# 은닉층1의 정의
model.add(Dense(H, activation='relu', kernel_initializer='he_normal', input_shape=(D,)))

# 은닉층2의 정의
model.add(Dense(H, activation='relu', kernel_initializer='he_normal'))

# 출력층
model.add(Dense(num_classes, activation='softmax', kernel_initializer='he_normal'))

# %%
# 모델의 컴파일
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'sgd',
              metrics=['accuracy'])

# 모델의 학습
history1 = model.fit(
    x_train, 
    y_train_ohe,
    batch_size = batch_size, 
    epochs = nb_epoch,
    verbose = 1, 
    validation_data = (x_test, y_test_ohe))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 2s 10ms/step - loss: 2.0936 - accuracy: 0.3248 - val_loss: 1.4474 - val_accuracy: 0.6950
# Epoch 2/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.2901 - accuracy: 0.7233 - val_loss: 0.8639 - val_accuracy: 0.8026
# Epoch 3/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.8213 - accuracy: 0.8078 - val_loss: 0.6370 - val_accuracy: 0.8410
# Epoch 4/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.6383 - accuracy: 0.8370 - val_loss: 0.5300 - val_accuracy: 0.8653
# Epoch 5/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.5346 - accuracy: 0.8605 - val_loss: 0.4669 - val_accuracy: 0.8756
# Epoch 6/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.4774 - accuracy: 0.8736 - val_loss: 0.4240 - val_accuracy: 0.8863
# Epoch 7/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.4389 - accuracy: 0.8824 - val_loss: 0.3951 - val_accuracy: 0.8930
# Epoch 8/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.4093 - accuracy: 0.8886 - val_loss: 0.3724 - val_accuracy: 0.8980
# Epoch 9/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3873 - accuracy: 0.8949 - val_loss: 0.3539 - val_accuracy: 0.9025
# Epoch 10/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3660 - accuracy: 0.8986 - val_loss: 0.3406 - val_accuracy: 0.9060
# Epoch 11/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3541 - accuracy: 0.9011 - val_loss: 0.3288 - val_accuracy: 0.9103
# Epoch 12/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3436 - accuracy: 0.9051 - val_loss: 0.3191 - val_accuracy: 0.9112
# Epoch 13/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3342 - accuracy: 0.9059 - val_loss: 0.3096 - val_accuracy: 0.9155
# Epoch 14/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3237 - accuracy: 0.9092 - val_loss: 0.3025 - val_accuracy: 0.9167
# Epoch 15/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3161 - accuracy: 0.9095 - val_loss: 0.2954 - val_accuracy: 0.9180
# Epoch 16/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3114 - accuracy: 0.9132 - val_loss: 0.2900 - val_accuracy: 0.9202
# Epoch 17/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3029 - accuracy: 0.9146 - val_loss: 0.2848 - val_accuracy: 0.9197
# Epoch 18/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2948 - accuracy: 0.9168 - val_loss: 0.2797 - val_accuracy: 0.9216
# Epoch 19/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2920 - accuracy: 0.9167 - val_loss: 0.2752 - val_accuracy: 0.9223
# Epoch 20/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2863 - accuracy: 0.9186 - val_loss: 0.2698 - val_accuracy: 0.9240
# Epoch 21/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2795 - accuracy: 0.9206 - val_loss: 0.2666 - val_accuracy: 0.9229
# Epoch 22/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2755 - accuracy: 0.9207 - val_loss: 0.2617 - val_accuracy: 0.9256
# Epoch 23/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2714 - accuracy: 0.9232 - val_loss: 0.2586 - val_accuracy: 0.9257
# Epoch 24/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2690 - accuracy: 0.9233 - val_loss: 0.2549 - val_accuracy: 0.9262
# Epoch 25/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2608 - accuracy: 0.9257 - val_loss: 0.2520 - val_accuracy: 0.9270
# Epoch 26/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2554 - accuracy: 0.9288 - val_loss: 0.2488 - val_accuracy: 0.9291
# Epoch 27/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2575 - accuracy: 0.9268 - val_loss: 0.2448 - val_accuracy: 0.9296
# Epoch 28/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2536 - accuracy: 0.9270 - val_loss: 0.2421 - val_accuracy: 0.9295
# Epoch 29/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2488 - accuracy: 0.9290 - val_loss: 0.2400 - val_accuracy: 0.9303
# Epoch 30/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2454 - accuracy: 0.9305 - val_loss: 0.2364 - val_accuracy: 0.9314
# Epoch 31/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2395 - accuracy: 0.9317 - val_loss: 0.2341 - val_accuracy: 0.9333
# Epoch 32/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2370 - accuracy: 0.9338 - val_loss: 0.2307 - val_accuracy: 0.9331
# Epoch 33/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2375 - accuracy: 0.9327 - val_loss: 0.2297 - val_accuracy: 0.9339
# Epoch 34/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2408 - accuracy: 0.9324 - val_loss: 0.2271 - val_accuracy: 0.9342
# Epoch 35/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2331 - accuracy: 0.9350 - val_loss: 0.2242 - val_accuracy: 0.9352
# Epoch 36/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2306 - accuracy: 0.9340 - val_loss: 0.2224 - val_accuracy: 0.9355
# Epoch 37/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2288 - accuracy: 0.9349 - val_loss: 0.2209 - val_accuracy: 0.9365
# Epoch 38/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2226 - accuracy: 0.9379 - val_loss: 0.2189 - val_accuracy: 0.9369
# Epoch 39/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2218 - accuracy: 0.9380 - val_loss: 0.2163 - val_accuracy: 0.9382
# Epoch 40/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2205 - accuracy: 0.9393 - val_loss: 0.2137 - val_accuracy: 0.9397
# Epoch 41/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2138 - accuracy: 0.9404 - val_loss: 0.2110 - val_accuracy: 0.9393
# Epoch 42/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2094 - accuracy: 0.9412 - val_loss: 0.2098 - val_accuracy: 0.9401
# Epoch 43/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2112 - accuracy: 0.9404 - val_loss: 0.2075 - val_accuracy: 0.9404
# Epoch 44/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2114 - accuracy: 0.9397 - val_loss: 0.2061 - val_accuracy: 0.9411
# Epoch 45/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2100 - accuracy: 0.9417 - val_loss: 0.2043 - val_accuracy: 0.9413
# Epoch 46/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2009 - accuracy: 0.9427 - val_loss: 0.2027 - val_accuracy: 0.9412
# Epoch 47/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2024 - accuracy: 0.9441 - val_loss: 0.2006 - val_accuracy: 0.9419
# Epoch 48/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2061 - accuracy: 0.9423 - val_loss: 0.1984 - val_accuracy: 0.9418
# Epoch 49/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2004 - accuracy: 0.9429 - val_loss: 0.1970 - val_accuracy: 0.9438
# Epoch 50/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1967 - accuracy: 0.9427 - val_loss: 0.1951 - val_accuracy: 0.9431

# %% [markdown]
# ### RmsProp

# %%
# Sequential 모델의 정의
model = Sequential()

# 은닉층1의 정의
model.add(Dense(H, activation='relu', kernel_initializer='he_normal', input_shape=(D,)))

# 은닉층2의 정의
model.add(Dense(H, activation='relu', kernel_initializer='he_normal'))

# 출력층
model.add(Dense(num_classes, activation='softmax', kernel_initializer='he_normal'))

# %%
# 모델의 컴파일
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics=['accuracy'])

# 모델의 학습
history2 = model.fit(
    x_train, 
    y_train_ohe,
    batch_size = batch_size, 
    epochs = nb_epoch,
    verbose = 1, 
    validation_data = (x_test, y_test_ohe))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.7809 - accuracy: 0.7761 - val_loss: 0.2756 - val_accuracy: 0.9128
# Epoch 2/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.2152 - accuracy: 0.9355 - val_loss: 0.1786 - val_accuracy: 0.9467
# Epoch 3/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.1464 - accuracy: 0.9568 - val_loss: 0.1467 - val_accuracy: 0.9531
# Epoch 4/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.1080 - accuracy: 0.9678 - val_loss: 0.1497 - val_accuracy: 0.9526
# Epoch 5/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0900 - accuracy: 0.9734 - val_loss: 0.1044 - val_accuracy: 0.9671
# Epoch 6/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0703 - accuracy: 0.9792 - val_loss: 0.0998 - val_accuracy: 0.9704
# Epoch 7/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0600 - accuracy: 0.9818 - val_loss: 0.0949 - val_accuracy: 0.9706
# Epoch 8/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0889 - val_accuracy: 0.9728
# Epoch 9/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0431 - accuracy: 0.9868 - val_loss: 0.0856 - val_accuracy: 0.9727
# Epoch 10/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0378 - accuracy: 0.9887 - val_loss: 0.0831 - val_accuracy: 0.9746
# Epoch 11/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0336 - accuracy: 0.9902 - val_loss: 0.0793 - val_accuracy: 0.9756
# Epoch 12/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0273 - accuracy: 0.9922 - val_loss: 0.1007 - val_accuracy: 0.9694
# Epoch 13/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0235 - accuracy: 0.9932 - val_loss: 0.0809 - val_accuracy: 0.9748
# Epoch 14/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0212 - accuracy: 0.9937 - val_loss: 0.0787 - val_accuracy: 0.9766
# Epoch 15/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 0.0730 - val_accuracy: 0.9790
# Epoch 16/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.0795 - val_accuracy: 0.9778
# Epoch 17/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0133 - accuracy: 0.9964 - val_loss: 0.0833 - val_accuracy: 0.9778
# Epoch 18/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 0.0845 - val_accuracy: 0.9770
# Epoch 19/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0097 - accuracy: 0.9974 - val_loss: 0.0869 - val_accuracy: 0.9761
# Epoch 20/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0088 - accuracy: 0.9977 - val_loss: 0.0927 - val_accuracy: 0.9771
# Epoch 21/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0835 - val_accuracy: 0.9788
# Epoch 22/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0932 - val_accuracy: 0.9785
# Epoch 23/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.0887 - val_accuracy: 0.9789
# Epoch 24/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0889 - val_accuracy: 0.9783
# Epoch 25/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0962 - val_accuracy: 0.9778
# Epoch 26/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.1042 - val_accuracy: 0.9772
# Epoch 27/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0982 - val_accuracy: 0.9778
# Epoch 28/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0953 - val_accuracy: 0.9789
# Epoch 29/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.1081 - val_accuracy: 0.9771
# Epoch 30/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0988 - val_accuracy: 0.9798
# Epoch 31/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1140 - val_accuracy: 0.9767
# Epoch 32/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1229 - val_accuracy: 0.9766
# Epoch 33/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1092 - val_accuracy: 0.9789
# Epoch 34/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1024 - val_accuracy: 0.9803
# Epoch 35/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1076 - val_accuracy: 0.9786
# Epoch 36/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1126 - val_accuracy: 0.9784
# Epoch 37/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.1084 - val_accuracy: 0.9791
# Epoch 38/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1163 - val_accuracy: 0.9772
# Epoch 39/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1235 - val_accuracy: 0.9789
# Epoch 40/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1143 - val_accuracy: 0.9793
# Epoch 41/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1160 - val_accuracy: 0.9800
# Epoch 42/50
# 118/118 [==============================] - 1s 10ms/step - loss: 8.4764e-04 - accuracy: 0.9998 - val_loss: 0.1215 - val_accuracy: 0.9795
# Epoch 43/50
# 118/118 [==============================] - 1s 10ms/step - loss: 9.6622e-04 - accuracy: 0.9998 - val_loss: 0.1282 - val_accuracy: 0.9782
# Epoch 44/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1284 - val_accuracy: 0.9778
# Epoch 45/50
# 118/118 [==============================] - 1s 10ms/step - loss: 6.6906e-04 - accuracy: 0.9999 - val_loss: 0.1510 - val_accuracy: 0.9747
# Epoch 46/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1255 - val_accuracy: 0.9791
# Epoch 47/50
# 118/118 [==============================] - 1s 10ms/step - loss: 7.2906e-04 - accuracy: 0.9998 - val_loss: 0.1274 - val_accuracy: 0.9798
# Epoch 48/50
# 118/118 [==============================] - 1s 10ms/step - loss: 7.7461e-04 - accuracy: 0.9997 - val_loss: 0.1309 - val_accuracy: 0.9793
# Epoch 49/50
# 118/118 [==============================] - 1s 11ms/step - loss: 5.9501e-04 - accuracy: 0.9998 - val_loss: 0.1373 - val_accuracy: 0.9789
# Epoch 50/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1297 - val_accuracy: 0.9793

# %% [markdown]
# ### Momentum

# %%
# Sequential 모델의 정의
model = Sequential()

# 은닉층1의 정의
model.add(Dense(H, activation='relu', kernel_initializer='he_normal', input_shape=(D,)))

# 은닉층2의 정의
model.add(Dense(H, activation='relu', kernel_initializer='he_normal'))

# 출력층
model.add(Dense(num_classes, activation='softmax', kernel_initializer='he_normal'))

# %%
# 모델의 컴파일
from keras import optimizers
sgd = optimizers.SGD(momentum = 0.9)
model.compile(loss = 'categorical_crossentropy',
              optimizer = sgd,
              metrics=['accuracy'])

# 모델의 학습
history3 = model.fit(
    x_train, 
    y_train_ohe,
    batch_size = batch_size, 
    epochs = nb_epoch,
    verbose = 1, 
    validation_data = (x_test, y_test_ohe))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 2s 11ms/step - loss: 1.4465 - accuracy: 0.5515 - val_loss: 0.3596 - val_accuracy: 0.8971
# Epoch 2/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.3555 - accuracy: 0.8998 - val_loss: 0.2777 - val_accuracy: 0.9179
# Epoch 3/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2821 - accuracy: 0.9184 - val_loss: 0.2438 - val_accuracy: 0.9279
# Epoch 4/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2427 - accuracy: 0.9302 - val_loss: 0.2181 - val_accuracy: 0.9348
# Epoch 5/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2184 - accuracy: 0.9363 - val_loss: 0.1995 - val_accuracy: 0.9404
# Epoch 6/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2002 - accuracy: 0.9427 - val_loss: 0.1870 - val_accuracy: 0.9440
# Epoch 7/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1806 - accuracy: 0.9481 - val_loss: 0.1701 - val_accuracy: 0.9489
# Epoch 8/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1673 - accuracy: 0.9519 - val_loss: 0.1623 - val_accuracy: 0.9498
# Epoch 9/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1553 - accuracy: 0.9550 - val_loss: 0.1536 - val_accuracy: 0.9534
# Epoch 10/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1460 - accuracy: 0.9576 - val_loss: 0.1480 - val_accuracy: 0.9547
# Epoch 11/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1408 - accuracy: 0.9595 - val_loss: 0.1369 - val_accuracy: 0.9584
# Epoch 12/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1286 - accuracy: 0.9636 - val_loss: 0.1352 - val_accuracy: 0.9595
# Epoch 13/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1244 - accuracy: 0.9645 - val_loss: 0.1295 - val_accuracy: 0.9614
# Epoch 14/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.1152 - accuracy: 0.9664 - val_loss: 0.1219 - val_accuracy: 0.9629
# Epoch 15/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1101 - accuracy: 0.9688 - val_loss: 0.1184 - val_accuracy: 0.9630
# Epoch 16/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1014 - accuracy: 0.9713 - val_loss: 0.1142 - val_accuracy: 0.9657
# Epoch 17/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1013 - accuracy: 0.9705 - val_loss: 0.1141 - val_accuracy: 0.9651
# Epoch 18/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0985 - accuracy: 0.9724 - val_loss: 0.1069 - val_accuracy: 0.9671
# Epoch 19/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0880 - accuracy: 0.9746 - val_loss: 0.1049 - val_accuracy: 0.9686
# Epoch 20/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0849 - accuracy: 0.9759 - val_loss: 0.1010 - val_accuracy: 0.9693
# Epoch 21/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0865 - accuracy: 0.9756 - val_loss: 0.0992 - val_accuracy: 0.9694
# Epoch 22/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0811 - accuracy: 0.9778 - val_loss: 0.0985 - val_accuracy: 0.9702
# Epoch 23/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0777 - accuracy: 0.9783 - val_loss: 0.0958 - val_accuracy: 0.9715
# Epoch 24/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0721 - accuracy: 0.9799 - val_loss: 0.0932 - val_accuracy: 0.9711
# Epoch 25/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0707 - accuracy: 0.9808 - val_loss: 0.0917 - val_accuracy: 0.9717
# Epoch 26/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0676 - accuracy: 0.9812 - val_loss: 0.0902 - val_accuracy: 0.9724
# Epoch 27/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0661 - accuracy: 0.9821 - val_loss: 0.0906 - val_accuracy: 0.9729
# Epoch 28/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0640 - accuracy: 0.9818 - val_loss: 0.0886 - val_accuracy: 0.9726
# Epoch 29/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0612 - accuracy: 0.9834 - val_loss: 0.0870 - val_accuracy: 0.9734
# Epoch 30/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0596 - accuracy: 0.9844 - val_loss: 0.0867 - val_accuracy: 0.9736
# Epoch 31/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0558 - accuracy: 0.9851 - val_loss: 0.0865 - val_accuracy: 0.9737
# Epoch 32/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0531 - accuracy: 0.9859 - val_loss: 0.0849 - val_accuracy: 0.9740
# Epoch 33/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0531 - accuracy: 0.9861 - val_loss: 0.0839 - val_accuracy: 0.9750
# Epoch 34/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0513 - accuracy: 0.9866 - val_loss: 0.0821 - val_accuracy: 0.9741
# Epoch 35/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0485 - accuracy: 0.9873 - val_loss: 0.0813 - val_accuracy: 0.9759
# Epoch 36/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0500 - accuracy: 0.9861 - val_loss: 0.0802 - val_accuracy: 0.9744
# Epoch 37/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0477 - accuracy: 0.9871 - val_loss: 0.0793 - val_accuracy: 0.9759
# Epoch 38/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0430 - accuracy: 0.9891 - val_loss: 0.0781 - val_accuracy: 0.9766
# Epoch 39/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0430 - accuracy: 0.9886 - val_loss: 0.0776 - val_accuracy: 0.9765
# Epoch 40/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0422 - accuracy: 0.9894 - val_loss: 0.0781 - val_accuracy: 0.9761
# Epoch 41/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0413 - accuracy: 0.9889 - val_loss: 0.0773 - val_accuracy: 0.9770
# Epoch 42/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0419 - accuracy: 0.9895 - val_loss: 0.0770 - val_accuracy: 0.9767
# Epoch 43/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0395 - accuracy: 0.9898 - val_loss: 0.0761 - val_accuracy: 0.9764
# Epoch 44/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0379 - accuracy: 0.9899 - val_loss: 0.0745 - val_accuracy: 0.9767
# Epoch 45/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0354 - accuracy: 0.9905 - val_loss: 0.0755 - val_accuracy: 0.9775
# Epoch 46/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0349 - accuracy: 0.9913 - val_loss: 0.0758 - val_accuracy: 0.9768
# Epoch 47/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0344 - accuracy: 0.9921 - val_loss: 0.0750 - val_accuracy: 0.9778
# Epoch 48/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0319 - accuracy: 0.9920 - val_loss: 0.0739 - val_accuracy: 0.9782
# Epoch 49/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0321 - accuracy: 0.9920 - val_loss: 0.0737 - val_accuracy: 0.9778
# Epoch 50/50
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0308 - accuracy: 0.9930 - val_loss: 0.0739 - val_accuracy: 0.9776

# %% [markdown]
# ### 그래프 표시 및 비교

# %%
#import matplotlib.pyplot as plt

# 학습 곡선 표시(손실함수의 값)
plt.figure(figsize=(8,6))
plt.plot(history1.history['val_loss'],label='SGD', lw=3, c='k')
plt.plot(history2.history['val_loss'],label='rmsprop', lw=3, c='b')
plt.plot(history3.history['val_loss'],label='momentum', lw=3, c='k', linestyle='dashed')
plt.ylim(0,2)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt

# 학습 곡선 표시(정확도)
plt.figure(figsize=(8,6))
plt.plot(history1.history['accuracy'],label='SGD', lw=3, c='k')
plt.plot(history2.history['accuracy'],label='rmsprop', lw=3, c='b')
plt.plot(history3.history['accuracy'],label='momentum', lw=3, c='k', linestyle='dashed')
plt.ylim(0.8,1)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## 11.6 과학습 대책

# %%
# 정답 데이터의 데이터 수
div = 8

# 근사다항식의 차원
dim = 8

# y = -x*4 + x**3 -3x**2 + 8x -7
p = [-1, 1, -3, 8, -7]

# x의 정의역[-2, 1]
xMin = -2
xMax = 1

# %% [markdown]
# $ f(x) = -x^4 + x^3 -3x^2 + 8x -7 + N(0,5) $

# %%
# x: xMin과 xMan의 사이를 div개로 분할한 벡터
x = np.linspace(xMin, xMax, num=div)

# xx: x를 10배 더 세밀한 간격으로 분할한 벡터
xx = np.linspace(xMin, xMax, num=div*10)

# y, yy: x, xx 각각의 벡터에 대해 다항식의 값을 계산한 벡터
y = np.polyval(p, x)
yy = np.polyval(p, xx)

# z: y에 정규분포의 노이즈를 추가하고 이것을 정답 데이터고 한다.
z = y + 5 * np.random.randn(div)

# %%
# 벡터 표시용 함수
def print_fix(x):
    [print('{:.3f}'.format(n)) for n in x]
    
# 모델을 인용하여 다항식의 계산을 표시
def print_fix_model(m):
    w = m.coef_.tolist()
    w[0] = m.intercept_
    print_fix(w)

# %%
# 다항식 행렬을 만들어 모델의 입력 변수로 한다.

# x**n의 벡터 계산용 함수
def f(x) :
    return [x**i for i in range(dim)]

# x: x벡터에서 다항식 2차원 배열을 만든 것
X = [f(x0) for x0 in x]

# Xx: xx벡터에서 다항식 2차원 배열을 만든 것
XX = [f(x0) for x0 in xx]

# %%
# 선형 모델 라이브러리의 로딩
from sklearn.linear_model import LinearRegression

# 모델의 초기화 및 학습
model = LinearRegression().fit(X, z)

# 예측값의 취득
yy_pred = model.predict(XX)

# %%
# Ridge 모델 라이브러리의 로딩
from sklearn.linear_model import Ridge

# 모델의 생성 및 학습
#model2 = Ridge(alpha=5).fit(X, z)
model2 = Ridge(alpha=0.5).fit(X, z)

# %%
# 예측값의 취득
yy_pred2 = model2.predict(XX)

# %%
# 그래프 표시
plt.figure(figsize=(8,6))
plt.plot(xx, yy, label='polynomial', lw=1, c='k')
plt.scatter(x, z, label='observed', s=50, c='k')
plt.plot(xx, yy_pred, label='linear regression', lw=3, c='k')
plt.plot(xx, yy_pred2, label='L2 regularizer', lw=3, c='b')
plt.xlabel('X')
plt.ylabel('Y')
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.legend(fontsize=14)
plt.show()
