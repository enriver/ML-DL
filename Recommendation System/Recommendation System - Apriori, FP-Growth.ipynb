# %%
import mlxtend
import numpy as np
import pandas as pd

# %%
data=np.array([
    ['milk','shirt','juice'],
    ['cabbage','shirt','beer'],
    ['milk','cabbage','shirt','beer'],
    ['cabbage','beer']
])

# %% [markdown]
# ### Apriori Algorithm

# %%
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit_transform(data)
df=pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     beer  cabbage  juice   milk  shirt
# 0  False    False   True   True   True
# 1   True     True  False  False   True
# 2   True     True  False   True   True
# 3   True     True  False  False  False

# %%
te.columns_
# Out:
# ['beer', 'cabbage', 'juice', 'milk', 'shirt']

# %%
# %%time

from mlxtend.frequent_patterns import apriori

apriori(df,min_support=0.5, use_colnames=True)
# Out:
# Wall time: 23.9 ms
#    support                itemsets
# 0     0.75                  (beer)
# 1     0.75               (cabbage)
# 2     0.50                  (milk)
# 3     0.75                 (shirt)
# 4     0.75         (cabbage, beer)
# 5     0.50           (shirt, beer)
# 6     0.50        (shirt, cabbage)
# 7     0.50           (milk, shirt)
# 8     0.50  (shirt, cabbage, beer)

# %% [markdown]
# alphabet order

# %% [markdown]
# ### FP-Growth

# %%
# %%time

from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.5, use_colnames=True)
# Out:
# Wall time: 2.99 ms
#    support                itemsets
# 0     0.75                 (shirt)
# 1     0.50                  (milk)
# 2     0.75               (cabbage)
# 3     0.75                  (beer)
# 4     0.50           (milk, shirt)
# 5     0.50        (shirt, cabbage)
# 6     0.75         (cabbage, beer)
# 7     0.50           (shirt, beer)
# 8     0.50  (shirt, cabbage, beer)

# %% [markdown]
# FP-Growth is faster than Apriori.

# %%
from mlxtend.frequent_patterns import association_rules

association_rules(fpgrowth(df,min_support=0.5, use_colnames=True), metric='confidence',min_threshold=0.5, support_only=False)
# Out:
#          antecedents       consequents  antecedent support  \
# 0             (milk)           (shirt)                0.50
# 1            (shirt)            (milk)                0.75
# 2            (shirt)         (cabbage)                0.75
# 3          (cabbage)           (shirt)                0.75
# 4          (cabbage)            (beer)                0.75
# 5             (beer)         (cabbage)                0.75
# 6            (shirt)            (beer)                0.75
# 7             (beer)           (shirt)                0.75
# 8   (shirt, cabbage)            (beer)                0.50
# 9      (shirt, beer)         (cabbage)                0.50
# 10   (beer, cabbage)           (shirt)                0.75
# 11           (shirt)   (beer, cabbage)                0.75
# 12         (cabbage)     (shirt, beer)                0.75
# 13            (beer)  (shirt, cabbage)                0.75
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0                 0.75     0.50    1.000000  1.333333    0.1250         inf
# 1                 0.50     0.50    0.666667  1.333333    0.1250        1.50
# 2                 0.75     0.50    0.666667  0.888889   -0.0625        0.75
# 3                 0.75     0.50    0.666667  0.888889   -0.0625        0.75
# 4                 0.75     0.75    1.000000  1.333333    0.1875         inf
# 5                 0.75     0.75    1.000000  1.333333    0.1875         inf
# 6                 0.75     0.50    0.666667  0.888889   -0.0625        0.75
# 7                 0.75     0.50    0.666667  0.888889   -0.0625        0.75
# 8                 0.75     0.50    1.000000  1.333333    0.1250         inf
# 9                 0.75     0.50    1.000000  1.333333    0.1250         inf
# 10                0.75     0.50    0.666667  0.888889   -0.0625        0.75
# 11                0.75     0.50    0.666667  0.888889   -0.0625        0.75
# 12                0.50     0.50    0.666667  1.333333    0.1250        1.50
# 13                0.50     0.50    0.666667  1.333333    0.1250        1.50
